# %% [markdown]
# # Set up visualization

# %%
# %matplotlib inline

# %%
from thunder import Colorize
image = Colorize.image
import seaborn as sns
sns.set_context("poster")

# %% [markdown]
# ## Create sources from fake data

# %%
data, ts, truth = tsc.makeExample('sources', centers=10, noise=1.0, returnParams=True)

# %% [markdown]
# ## Look at the data compared to ground truth

# %%
im = data.mean()

# %%
image(im)

# %%
image(truth.masks((100,200), base=im, outline=True))

# %% [markdown]
# ## Run an algorithm

# %%
from thunder import SourceExtraction

# %%
model = SourceExtraction('nmf').fit(data, size=(25,25))

# %%
image(model.masks((100,200), base=im))
